# %%
from csv_module import csv_downloader, send_data_to_db

# %%
CSV_URL = "https://drive.usercontent.google.com/u/0/uc?id=1TQRSONybodmFG7yBrMuCxb2JRFVaowJR&export=download"

flights = csv_downloader(csv_url=CSV_URL)

# %%
flights.head()
# Out:
#    actual_arrival_time  actual_flight_time  actual_departure_time  air_time  \
# 0               1339.0               224.0                  655.0     200.0
# 1                951.0               115.0                  656.0      97.0
# 2               1429.0               180.0                 1129.0     152.0
# 3                944.0               140.0                  724.0     108.0
# 4               1300.0               146.0                 1034.0     132.0
#
#    air_traffic_delay airline_code          airline_name  arrival_delay  \
# 0                  0           DL  Delta Air Lines Inc.          -17.0
# 1                  0           DL  Delta Air Lines Inc.          -17.0
# 2                  0           DL  Delta Air Lines Inc.          -20.0
# 3                  0           DL  Delta Air Lines Inc.            3.0
# 4                  0           DL  Delta Air Lines Inc.          -25.0
#
#   cancellation_reason  carrier_delay  ... origin_state  \
# ...

# %%
flights[flights['was_cancelled'] == True]
# Out:
#        actual_arrival_time  actual_flight_time  actual_departure_time  \
# 10077                  NaN                 NaN                 1918.0
# 10831                  NaN                 NaN                    NaN
# 12350                  NaN                 NaN                    NaN
# 26096                  NaN                 NaN                    NaN
# 26221                  NaN                 NaN                    NaN
# ...                    ...                 ...                    ...
# 44803                  NaN                 NaN                    NaN
# 44834                  NaN                 NaN                    NaN
# 44845                  NaN                 NaN                    NaN
# 44870                  NaN                 NaN                    NaN
# 44945                  NaN                 NaN                    NaN
#
#        air_time  air_traffic_delay airline_code             airline_name  \
# ...

# %%
flights[flights['was_cancelled'] == False]
# Out:
#        actual_arrival_time  actual_flight_time  actual_departure_time  \
# 0                   1339.0               224.0                  655.0
# 1                    951.0               115.0                  656.0
# 2                   1429.0               180.0                 1129.0
# 3                    944.0               140.0                  724.0
# 4                   1300.0               146.0                 1034.0
# ...                    ...                 ...                    ...
# 44995               2330.0                97.0                 2153.0
# 44996               2318.0                92.0                 2146.0
# 44997               2317.0                92.0                 2145.0
# 44998               2315.0                90.0                 2145.0
# 44999               2316.0                92.0                 2144.0
#
#        air_time  air_traffic_delay airline_code          airline_name  \
# ...

# %%
succeesful_flights = flights[flights['was_cancelled'] == True]
unsuccessful_flights = flights[flights['was_cancelled'] == False]

print(succeesful_flights.shape)
print(unsuccessful_flights.shape)
# Out:
# (607, 30)
# (44393, 30)

# %%
table1 = "completed_flights"
table2 = "failed_flights"


send_data_to_db(df=succeesful_flights, table_name=table1)
send_data_to_db(df=unsuccessful_flights, table_name=table2)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File /opt/anaconda3/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3302, in Engine.raw_connection(self)
#    3281 """Return a "raw" DBAPI connection from the connection pool.
#    3282
#    3283 The returned object is a proxied version of the DBAPI
#    (...)
#    3300
#    3301 """
# -> 3302 return self.pool.connect()
#
# File /opt/anaconda3/lib/python3.12/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
# ...
